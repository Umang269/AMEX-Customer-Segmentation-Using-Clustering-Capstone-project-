# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df=pd.read_csv('CC GENERAL.csv')

# %% [markdown]
# - **Data Understanding and Exploration**

# %%
df.shape
# Out:
# (8950, 18)

# %%
df.info() #data understanding
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %%
df.drop(columns='CUST_ID').describe() #exploring data
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# 25%                  0.000000      0.000000             0.083333
# 50%                 89.000000      0.000000             0.500000
# 75%                468.637500   1113.821139             0.916667
# max              22500.000000  47137.211760             1.000000
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                 8950.000000                       8950.000000
# mean                     0.202458                          0.364437
# std                      0.298336                          0.397448
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.000000
# 50%                      0.083333                          0.166667
# 75%                      0.300000                          0.750000
# max                      1.000000                          1.000000
#
#        CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# count             8950.000000       8950.000000    8950.000000   8949.000000
# mean                 0.135144          3.248827      14.709832   4494.449450
# std                  0.200121          6.824647      24.857649   3638.815725
# min                  0.000000          0.000000       0.000000     50.000000
# 25%                  0.000000          0.000000       1.000000   1600.000000
# 50%                  0.000000          0.000000       7.000000   3000.000000
# 75%                  0.222222          4.000000      17.000000   6500.000000
# max                  1.500000        123.000000     358.000000  30000.000000
#
#            PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT       TENURE
# count   8950.000000       8637.000000       8950.000000  8950.000000
# mean    1733.143852        864.206542          0.153715    11.517318
# std     2895.063757       2372.446607          0.292499     1.338331
# min        0.000000          0.019163          0.000000     6.000000
# 25%      383.276166        169.123707          0.000000    12.000000
# 50%      856.901546        312.343947          0.000000    12.000000
# 75%     1901.134317        825.485459          0.142857    12.000000
# max    50721.483360      76406.207520          1.000000    12.000000

# %%
df.head(10)
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
# 5  C10006  1809.828751           1.000000    1333.28              0.00
# 6  C10007   627.260806           1.000000    7091.01           6402.63
# 7  C10008  1823.652743           1.000000     436.20              0.00
# 8  C10009  1014.926473           1.000000     861.49            661.49
# 9  C10010   152.225975           0.545455    1281.60           1281.60
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   95.40      0.000000             0.166667
# 1                    0.00   6442.945483             0.000000
# 2                    0.00      0.000000             1.000000
# 3                    0.00    205.788017             0.083333
# 4                    0.00      0.000000             0.083333
# 5                 1333.28      0.000000             0.666667
# 6                  688.38      0.000000             1.000000
# 7                  436.20      0.000000             1.000000
# 8                  200.00      0.000000             0.333333
# 9                    0.00      0.000000             0.166667
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
# 5                    0.000000                          0.583333
# 6                    1.000000                          1.000000
# 7                    0.000000                          1.000000
# 8                    0.083333                          0.250000
# 9                    0.166667                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
# 5                0.000000                 0              8        1800.0
# 6                0.000000                 0             64       13500.0
# 7                0.000000                 0             12        2300.0
# 8                0.000000                 0              5        7000.0
# 9                0.000000                 0              3       11000.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12
# 5  1400.057770       2407.246035          0.000000      12
# 6  6354.314328        198.065894          1.000000      12
# 7   679.065082        532.033990          0.000000      12
# 8   688.278568        311.963409          0.000000      12
# 9  1164.770591        100.302262          0.000000      12

# %%
df.duplicated().sum() #checking duplicates
# Out:
# 0

# %%
df.isnull().sum() #cheching null values
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
sns.boxplot(df) #CHECKING OUTLIERS
# Out:
# <Axes: >

# %% [markdown]
# - **Data Cleaning**

# %%
df.drop(columns='CUST_ID',inplace=True) #Droping Unwanted columns

# %%
df[df['MINIMUM_PAYMENTS'].isnull()]
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 3     1666.670542           0.636364    1499.00           1499.00
# 45    2242.311686           1.000000     437.00             97.00
# 47    3910.111237           1.000000       0.00              0.00
# 54       6.660517           0.636364     310.00              0.00
# 55    1311.995984           1.000000    1283.90           1283.90
# ...           ...                ...        ...               ...
# 8919    14.524779           0.333333     152.00            152.00
# 8929   371.527312           0.333333       0.00              0.00
# 8935   183.817004           1.000000     465.90              0.00
# 8944   193.571722           0.833333    1012.73           1012.73
# 8946    19.183215           1.000000     300.00              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 3                        0.0    205.788017             0.083333
# 45                     340.0    184.648692             0.333333
# 47                       0.0   1980.873201             0.000000
# 54                     310.0      0.000000             0.666667
# 55                       0.0      0.000000             0.250000
# ...                      ...           ...                  ...
# 8919                     0.0      0.000000             0.333333
# 8929                     0.0   1465.407927             0.000000
# 8935                   465.9      0.000000             1.000000
# 8944                     0.0      0.000000             0.333333
# 8946                   300.0      0.000000             1.000000
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 3                       0.083333                          0.000000
# 45                      0.083333                          0.333333
# 47                      0.000000                          0.000000
# 54                      0.000000                          0.666667
# 55                      0.250000                          0.000000
# ...                          ...                               ...
# 8919                    0.333333                          0.000000
# 8929                    0.000000                          0.000000
# 8935                    0.000000                          0.833333
# 8944                    0.333333                          0.000000
# 8946                    0.000000                          0.833333
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 3                   0.083333                 1              1        7500.0
# 45                  0.166667                 2              5        2400.0
# 47                  0.500000                 7              0        4200.0
# 54                  0.000000                 0              8        1000.0
# 55                  0.000000                 0              6        6000.0
# ...                      ...               ...            ...           ...
# 8919                0.000000                 0              2        1500.0
# 8929                0.166667                 5              0        1500.0
# 8935                0.000000                 0              6        1500.0
# 8944                0.000000                 0              2        4000.0
# 8946                0.000000                 0              6        1000.0
#
#         PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 3       0.000000               NaN               0.0      12
# 45      0.000000               NaN               0.0      12
# 47      0.000000               NaN               0.0      12
# 54    417.016763               NaN               0.0      12
# 55      0.000000               NaN               0.0      12
# ...          ...               ...               ...     ...
# 8919    0.000000               NaN               0.0       6
# 8929    0.000000               NaN               0.0       6
# 8935    0.000000               NaN               0.0       6
# 8944    0.000000               NaN               0.0       6
# 8946  275.861322               NaN               0.0       6
#
# [313 rows x 17 columns]

# %%
df['MINIMUM_PAYMENTS'].fillna(df['MINIMUM_PAYMENTS'].median(),inplace=True) #Replaced with meaian because column contain outliers

# %%
df[df['CREDIT_LIMIT'].isnull()]
# Out:
#         BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 5203  18.400472           0.166667        0.0               0.0
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 5203                     0.0    186.853063                  0.0
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 5203                         0.0                               0.0
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 5203                0.166667                 1              0           NaN
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 5203  9.040017         14.418723               0.0       6

# %%
df.drop(index=5203,inplace=True) #Droping the missing value of CREDIT_LIMIT

# %%
df.isnull().sum() #Again checking null values
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %% [markdown]
# - We have to retrain outliers in this data set because they are important

# %%
dfc=df.corr()

# %%
sns.heatmap(dfc)
# Out:
# <Axes: >

# %%
dfa=df.copy() #copying for transformation and modeling

# %% [markdown]
# - **Data Tranformation**

# %%
df.skew() #checking Distribution
# Out:
# BALANCE                              2.393270
# BALANCE_FREQUENCY                   -2.024193
# PURCHASES                            8.143969
# ONEOFF_PURCHASES                    10.044622
# INSTALLMENTS_PURCHASES               7.298823
# CASH_ADVANCE                         5.166323
# PURCHASES_FREQUENCY                  0.059970
# ONEOFF_PURCHASES_FREQUENCY           1.535453
# PURCHASES_INSTALLMENTS_FREQUENCY     0.509023
# CASH_ADVANCE_FREQUENCY               1.828644
# CASH_ADVANCE_TRX                     5.720976
# PURCHASES_TRX                        4.630493
# CREDIT_LIMIT                         1.522464
# PAYMENTS                             5.907465
# MINIMUM_PAYMENTS                    13.851853
# PRC_FULL_PAYMENT                     1.942641
# TENURE                              -2.944788
# dtype: float64

# %%
df['BALANCE'] = df['BALANCE']**(1/4)

# %%
df['BALANCE_FREQUENCY'] = df['BALANCE_FREQUENCY']**11

# %%
df['PURCHASES'] = df['PURCHASES']**(1/4)

# %%
df['ONEOFF_PURCHASES'],p = stats.boxcox(df['ONEOFF_PURCHASES']+0.001)

# %%
df['INSTALLMENTS_PURCHASES'],p = stats.boxcox(df['INSTALLMENTS_PURCHASES']+0.001)

# %%
df['CASH_ADVANCE'],p = stats.boxcox(df['CASH_ADVANCE']+0.001)

# %%
df['ONEOFF_PURCHASES_FREQUENCY'] = df['ONEOFF_PURCHASES_FREQUENCY']**(1/8)

# %%
df['CASH_ADVANCE_FREQUENCY'] = np.log(df['CASH_ADVANCE_FREQUENCY']+0.001)

# %%
df['CREDIT_LIMIT'],p=stats.boxcox(df['CREDIT_LIMIT']+0.001)

# %%
df['PAYMENTS'],p = stats.boxcox(df['PAYMENTS']+0.001)

# %%
df['MINIMUM_PAYMENTS'],p = stats.boxcox(df['MINIMUM_PAYMENTS']+0.001)

# %%
df['PRC_FULL_PAYMENT'],p = stats.boxcox(df['PRC_FULL_PAYMENT']+0.001)

# %%
df.skew() #Re-checking Distribution
# Out:
# BALANCE                            -0.009866
# BALANCE_FREQUENCY                  -0.924189
# PURCHASES                          -0.116031
# ONEOFF_PURCHASES                   -0.005484
# INSTALLMENTS_PURCHASES             -0.164074
# CASH_ADVANCE                        0.108957
# PURCHASES_FREQUENCY                 0.059970
# ONEOFF_PURCHASES_FREQUENCY         -0.002837
# PURCHASES_INSTALLMENTS_FREQUENCY    0.509023
# CASH_ADVANCE_FREQUENCY              0.167760
# CASH_ADVANCE_TRX                    5.720976
# PURCHASES_TRX                       4.630493
# CREDIT_LIMIT                       -0.009721
# PAYMENTS                            0.158047
# MINIMUM_PAYMENTS                   -0.004040
# PRC_FULL_PAYMENT                    0.685607
# TENURE                             -2.944788
# dtype: float64

# %% [markdown]
# # Modeling

# %% [markdown]
# - **K-Means**

# %%
from sklearn.cluster import KMeans #checking WCSS value
wcss = []
for i in range(1,11):
    m = KMeans(n_clusters=i)
    m.fit(df)
    wcss.append(m.inertia_)

# %%
plt.plot(range(1,11),wcss,marker='o')
plt.xticks(range(1,11))
plt.xlabel('no. of clusters')
plt.ylabel('WCSS')
plt.title("Elbow Method for Optimal k")
plt.show()

# %%
from sklearn.cluster import KMeans
m = KMeans(n_clusters=5)
m.fit(df)
dfa['K_means_result']= m.predict(df)

# %% [markdown]
# - **Hierarical clustering**

# %%
from sklearn.cluster import AgglomerativeClustering
m = AgglomerativeClustering(n_clusters=5)
dfa['H_result'] = m.fit_predict(df)

# %% [markdown]
# - **DBSCAN**

# %%
from sklearn.cluster import DBSCAN
for i in range(1,11):
    for j in range(3,11):
        m = DBSCAN(eps=i, min_samples=j)
        labels = m.fit_predict(df)
        if pd.Series('labels').nunique() == 5:
            break
print(i,j)
# Out:
# 10 10

# %%
from sklearn.cluster import DBSCAN
m = DBSCAN(eps=10, min_samples=10)
dfa['DBSCAN_result'] = m.fit_predict(df)

# %% [markdown]
#  # **Observation**

# %% [markdown]
# - High-value - km==3 because no of purchase trx is very high
# - High-risk  -  km==2 because most will withdraw cash which shows lack of liquidity
# - Inactive customers
# - Enabling potential targeted marketing strategies

# %%
dfa[dfa['K_means_result']==0]
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 1     3202.467416           0.909091       0.00              0.00
# 12    1516.928620           1.000000    3217.99           2500.23
# 13     921.693369           1.000000    2137.93            419.96
# 17      41.089489           0.454545     519.00              0.00
# 33     125.660453           1.000000     636.79            636.79
# ...           ...                ...        ...               ...
# 8940   130.838554           1.000000     591.24              0.00
# 8942    40.829749           1.000000     113.28              0.00
# 8945    28.493517           1.000000     291.12              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 1                       0.00   6442.945483             0.000000
# 12                    717.76      0.000000             1.000000
# 13                   1717.97      0.000000             0.750000
# 17                    519.00      0.000000             0.416667
# 33                      0.00      0.000000             0.916667
# ...                      ...           ...                  ...
# 8940                  591.24      0.000000             1.000000
# 8942                  113.28      0.000000             1.000000
# 8945                  291.12      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 1                       0.000000                          0.000000
# 12                      0.250000                          0.916667
# 13                      0.166667                          0.750000
# 17                      0.000000                          0.333333
# 33                      0.916667                          0.000000
# ...                          ...                               ...
# 8940                    0.000000                          0.833333
# 8942                    0.000000                          0.833333
# 8945                    0.000000                          0.833333
# 8947                    0.000000                          0.666667
# 8948                    0.000000                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 1                   0.250000                 4              0        7000.0
# 12                  0.000000                 0             26        3000.0
# 13                  0.000000                 0             26        7500.0
# 17                  0.000000                 0              8        2500.0
# 33                  0.000000                 0             11        1200.0
# ...                      ...               ...            ...           ...
# 8940                0.000000                 0              6        1000.0
# 8942                0.000000                 0              6        1000.0
# 8945                0.000000                 0              6        1000.0
# 8947                0.000000                 0              5        1000.0
# 8948                0.166667                 2              0         500.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  K_means_result  \
# 1     4103.032597       1072.340217          0.222222      12               0
# 12     608.263689        490.207013          0.250000      12               0
# 13    1655.891435        251.137986          0.083333      12               0
# 17     254.590662         73.203221          0.250000      12               0
# 33     423.449696        196.301885          0.300000      12               0
# ...           ...               ...               ...     ...             ...
# 8940   475.523262         82.771320          1.000000       6               0
# 8942    94.488828         86.283101          0.250000       6               0
# 8945   325.594462         48.886365          0.500000       6               0
# 8947    81.270775         82.418369          0.250000       6               0
# 8948    52.549959         55.755628          0.250000       6               0
#
#       H_result  DBSCAN_result
# 1            3              1
# 12           1              3
# 13           1              3
# 17           3              3
# 33           3              3
# ...        ...            ...
# 8940         3              3
# 8942         3              3
# 8945         3              3
# 8947         3              3
# 8948         3              1
#
# [2640 rows x 20 columns]

# %%
dfa[dfa['K_means_result']==1]
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# 9      152.225975           0.545455    1281.60           1281.60
# 11     630.794744           0.818182    1492.18           1492.18
# ...           ...                ...        ...               ...
# 8937   163.001629           0.666667       0.00              0.00
# 8939   728.352548           1.000000     734.40            734.40
# 8941  5967.475270           0.833333     214.55              0.00
# 8943     5.871712           0.500000      20.90             20.90
# 8944   193.571722           0.833333    1012.73           1012.73
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 3                       0.00    205.788017             0.083333
# 4                       0.00      0.000000             0.083333
# 9                       0.00      0.000000             0.166667
# 11                      0.00      0.000000             0.250000
# ...                      ...           ...                  ...
# 8937                    0.00    274.440466             0.000000
# 8939                    0.00    239.891038             0.333333
# 8941                  214.55   8555.409326             0.833333
# 8943                    0.00      0.000000             0.166667
# 8944                    0.00      0.000000             0.333333
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 3                       0.083333                          0.000000
# 4                       0.083333                          0.000000
# 9                       0.166667                          0.000000
# 11                      0.250000                          0.000000
# ...                          ...                               ...
# 8937                    0.000000                          0.000000
# 8939                    0.333333                          0.000000
# 8941                    0.000000                          0.666667
# 8943                    0.166667                          0.000000
# 8944                    0.333333                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 3                   0.083333                 1              1        7500.0
# 4                   0.000000                 0              1        1200.0
# 9                   0.000000                 0              3       11000.0
# 11                  0.000000                 0              6        2000.0
# ...                      ...               ...            ...           ...
# 8937                0.166667                 3              0        1000.0
# 8939                0.166667                 2              2        1000.0
# 8941                0.666667                13              5        9000.0
# 8943                0.000000                 0              1         500.0
# 8944                0.000000                 0              2        4000.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  K_means_result  \
# 0      201.802084        139.509787               0.0      12               1
# 3        0.000000        312.343947               0.0      12               1
# 4      678.334763        244.791237               0.0      12               1
# 9     1164.770591        100.302262               0.0      12               1
# 11     705.618627        155.549069               0.0      12               1
# ...           ...               ...               ...     ...             ...
# 8937   117.738787         60.792450               0.0       6               1
# 8939    72.530037        110.950798               0.0       6               1
# 8941   966.202912        861.949906               0.0       6               1
# 8943    58.644883         43.473717               0.0       6               1
# 8944     0.000000        312.343947               0.0       6               1
#
#       H_result  DBSCAN_result
# 0            0              0
# 3            0              2
# 4            0              0
# 9            0              0
# 11           0              0
# ...        ...            ...
# 8937         0              2
# 8939         0              2
# 8941         0              2
# 8943         0              0
# 8944         0              0
#
# [3277 rows x 20 columns]

# %%
dfa[dfa['K_means_result']==2]
# Out:
#            BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 125    2392.917738           1.000000   12462.44          12462.44
# 138   19043.138560           1.000000   22009.92           9449.07
# 153   13673.079610           1.000000    9792.23           3959.81
# 171     975.942008           1.000000   10221.35           7141.38
# 204    4559.779234           1.000000   10848.50           8208.00
# ...            ...                ...        ...               ...
# 7661    717.764625           1.000000    3358.25           3358.25
# 7729   1006.592714           0.909091    1341.62           1341.62
# 7847   2030.838228           1.000000    3165.54           1591.65
# 7911    530.574252           1.000000    5221.42           2202.78
# 8541   3326.323283           1.000000    8209.77           2218.28
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 125                     0.00      0.000000             0.916667
# 138                 12560.85      0.000000             1.000000
# 153                  5832.42   2444.445738             1.000000
# 171                  3079.97   1620.685551             1.000000
# 204                  2640.50      0.000000             1.000000
# ...                      ...           ...                  ...
# 7661                    0.00      0.000000             1.000000
# 7729                    0.00      0.000000             0.363636
# 7847                 1573.89      0.000000             1.000000
# 7911                 3018.64      0.000000             1.000000
# 8541                 5991.49      0.000000             1.000000
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 125                     0.916667                          0.000000
# 138                     0.750000                          1.000000
# 153                     0.750000                          1.000000
# 171                     1.000000                          0.833333
# 204                     0.666667                          1.000000
# ...                          ...                               ...
# 7661                    1.000000                          0.000000
# 7729                    0.363636                          0.000000
# 7847                    0.583333                          1.000000
# 7911                    1.000000                          1.000000
# 8541                    0.416667                          1.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 125                 0.000000                 0            217        2800.0
# 138                 0.000000                 0            216       18000.0
# 153                 0.750000                26            216       20000.0
# 171                 0.583333                18            130       10500.0
# 204                 0.000000                 0            123        7500.0
# ...                      ...               ...            ...           ...
# 7661                0.000000                 0            127        4000.0
# 7729                0.000000                 0            186        1200.0
# 7847                0.000000                 0            151        6000.0
# 7911                0.000000                 0            135        3000.0
# 8541                0.000000                 0            130       10000.0
#
#           PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  \
# 125   11628.715570       2000.990921          0.000000      12
# 138   23018.575830      18621.013310          0.000000      12
# 153   11717.307940       6042.391629          0.000000      12
# 171   10693.495850        347.641073          0.750000      12
# 204    9423.715495       2925.275522          0.000000      12
# ...            ...               ...               ...     ...
# 7661   2370.592652        202.790825          0.000000      12
# 7729   1444.198295        708.609079          0.000000      11
# 7847   1872.134044        438.771190          0.000000      12
# 7911   4590.877822        191.304474          0.583333      12
# 8541   1942.074765        702.905059          0.083333      12
#
#       K_means_result  H_result  DBSCAN_result
# 125                2         4             -1
# 138                2         4             -1
# 153                2         4             -1
# 171                2         2             -1
# 204                2         2              0
# ...              ...       ...            ...
# 7661               2         2             -1
# 7729               2         4             -1
# 7847               2         2             -1
# 7911               2         2              3
# 8541               2         2              3
#
# [82 rows x 20 columns]

# %%
dfa[dfa['K_means_result']==3]
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 2     2495.148862           1.000000     773.17            773.17
# 5     1809.828751           1.000000    1333.28              0.00
# 7     1823.652743           1.000000     436.20              0.00
# 8     1014.926473           1.000000     861.49            661.49
# 10    1293.124939           1.000000     920.12              0.00
# ...           ...                ...        ...               ...
# 8921     3.417407           0.500000      57.42              0.00
# 8933   735.652303           1.000000     619.60            255.62
# 8935   183.817004           1.000000     465.90              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 2                       0.00      0.000000             1.000000
# 5                    1333.28      0.000000             0.666667
# 7                     436.20      0.000000             1.000000
# 8                     200.00      0.000000             0.333333
# 10                    920.12      0.000000             1.000000
# ...                      ...           ...                  ...
# 8921                   57.42      0.000000             1.000000
# 8933                  363.98    546.902403             1.000000
# 8935                  465.90      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 2                       1.000000                          0.000000
# 5                       0.000000                          0.583333
# 7                       0.000000                          1.000000
# 8                       0.083333                          0.250000
# 10                      0.000000                          1.000000
# ...                          ...                               ...
# 8921                    0.000000                          0.833333
# 8933                    0.166667                          0.833333
# 8935                    0.000000                          0.833333
# 8946                    0.000000                          0.833333
# 8949                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 2                   0.000000                 0             12        7500.0
# 5                   0.000000                 0              8        1800.0
# 7                   0.000000                 0             12        2300.0
# 8                   0.000000                 0              5        7000.0
# 10                  0.000000                 0             12        1200.0
# ...                      ...               ...            ...           ...
# 8921                0.000000                 0              6        1500.0
# 8933                0.166667                 5             16        1000.0
# 8935                0.000000                 0              6        1500.0
# 8946                0.000000                 0              6        1000.0
# 8949                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  K_means_result  \
# 2      622.066742        627.284787               0.0      12               3
# 5     1400.057770       2407.246035               0.0      12               3
# 7      679.065082        532.033990               0.0      12               3
# 8      688.278568        311.963409               0.0      12               3
# 10    1083.301007       2172.697765               0.0      12               3
# ...           ...               ...               ...     ...             ...
# 8921    68.462579         20.714869               0.0       6               3
# 8933   106.138603        337.294767               0.0       6               3
# 8935     0.000000        312.343947               0.0       6               3
# 8946   275.861322        312.343947               0.0       6               3
# 8949    63.165404         88.288956               0.0       6               3
#
#       H_result  DBSCAN_result
# 2            0              0
# 5            0              0
# 7            0              0
# 8            0              0
# 10           0              0
# ...        ...            ...
# 8921         0              0
# 8933         0              2
# 8935         0              0
# 8946         0              0
# 8949         0              2
#
# [2232 rows x 20 columns]

# %%
dfa[dfa['K_means_result']==4]
# Out:
#            BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 6       627.260806           1.000000    7091.01           6402.63
# 21     6369.531318           1.000000    6359.95           5910.04
# 30    12136.219960           1.000000    3038.01           1013.20
# 31     1162.273324           1.000000    1347.71            400.00
# 48      229.867179           1.000000    2390.60           1402.93
# ...            ...                ...        ...               ...
# 8662    599.909949           1.000000    4947.32           3149.59
# 8689    368.318662           0.909091    8053.95           8053.95
# 8707     78.448912           1.000000    1875.18            977.85
# 8737   2533.618119           0.909091    5633.83           2985.92
# 8856    227.220411           1.000000    1387.60            288.54
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 6                     688.38      0.000000             1.000000
# 21                    449.91    229.028245             1.000000
# 30                   2024.81   3183.583301             1.000000
# 31                    947.71    175.815755             1.000000
# 48                    987.67      0.000000             1.000000
# ...                      ...           ...                  ...
# 8662                 1797.73      0.000000             1.000000
# 8689                    0.00      0.000000             0.833333
# 8707                  897.33      0.000000             1.000000
# 8737                 2647.91   2451.807788             0.916667
# 8856                 1099.06    107.660394             1.000000
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 6                       1.000000                          1.000000
# 21                      0.916667                          1.000000
# 30                      0.166667                          1.000000
# 31                      0.083333                          1.000000
# 48                      0.666667                          1.000000
# ...                          ...                               ...
# 8662                    1.000000                          0.916667
# 8689                    0.833333                          0.000000
# 8707                    0.833333                          0.916667
# 8737                    0.500000                          0.750000
# 8856                    0.875000                          0.875000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 6                   0.000000                 0             64       13500.0
# 21                  0.333333                 6             92       11250.0
# 30                  0.500000                10             64       13000.0
# 31                  0.166667                 2             45        6000.0
# 48                  0.000000                 0             87        3300.0
# ...                      ...               ...            ...           ...
# 8662                0.000000                 0             73        3000.0
# 8689                0.000000                 0             46        2000.0
# 8707                0.000000                 0             78        1200.0
# 8737                0.333333                16             82        9000.0
# 8856                0.125000                 1             71        1000.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  K_means_result  \
# 6     6354.314328        198.065894          1.000000      12               4
# 21    2077.959051       1659.775075          0.000000      12               4
# 30    4230.323491       3292.015030          0.000000      12               4
# 31     645.998299        256.848991          0.000000      12               4
# 48    2543.953559        175.657825          0.916667      12               4
# ...           ...               ...               ...     ...             ...
# 8662  5024.430008        218.172915          0.083333      12               4
# 8689  7966.582037        219.761189          0.777778      12               4
# 8707  1656.503571        172.161277          1.000000      12               4
# 8737  8176.953944        602.963244          0.000000      12               4
# 8856  1217.473837        136.283049          0.142857       8               4
#
#       H_result  DBSCAN_result
# 6            1              3
# 21           2              2
# 30           1              2
# 31           1              2
# 48           2              3
# ...        ...            ...
# 8662         2              3
# 8689         1              3
# 8707         2              3
# 8737         2             -1
# 8856         1             -1
#
# [718 rows x 20 columns]

# %%
dfa[(dfa['K_means_result']==0) & (dfa['PURCHASES_TRX']>0)]
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 12    1516.928620           1.000000    3217.99           2500.23
# 13     921.693369           1.000000    2137.93            419.96
# 17      41.089489           0.454545     519.00              0.00
# 33     125.660453           1.000000     636.79            636.79
# 39    1411.602230           0.454545     963.24            963.24
# ...           ...                ...        ...               ...
# 8936   108.977282           1.000000     712.50              0.00
# 8940   130.838554           1.000000     591.24              0.00
# 8942    40.829749           1.000000     113.28              0.00
# 8945    28.493517           1.000000     291.12              0.00
# 8947    23.398673           0.833333     144.40              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 12                    717.76      0.000000             1.000000
# 13                   1717.97      0.000000             0.750000
# 17                    519.00      0.000000             0.416667
# 33                      0.00      0.000000             0.916667
# 39                      0.00   6173.682877             0.083333
# ...                      ...           ...                  ...
# 8936                  712.50      0.000000             1.000000
# 8940                  591.24      0.000000             1.000000
# 8942                  113.28      0.000000             1.000000
# 8945                  291.12      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 12                      0.250000                          0.916667
# 13                      0.166667                          0.750000
# 17                      0.000000                          0.333333
# 33                      0.916667                          0.000000
# 39                      0.083333                          0.000000
# ...                          ...                               ...
# 8936                    0.000000                          0.833333
# 8940                    0.000000                          0.833333
# 8942                    0.000000                          0.833333
# 8945                    0.000000                          0.833333
# 8947                    0.000000                          0.666667
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 12                  0.000000                 0             26        3000.0
# 13                  0.000000                 0             26        7500.0
# 17                  0.000000                 0              8        2500.0
# 33                  0.000000                 0             11        1200.0
# 39                  0.333333                 6              6        7500.0
# ...                      ...               ...            ...           ...
# 8936                0.000000                 0              6        1000.0
# 8940                0.000000                 0              6        1000.0
# 8942                0.000000                 0              6        1000.0
# 8945                0.000000                 0              6        1000.0
# 8947                0.000000                 0              5        1000.0
#
#           PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  \
# 12      608.263689        490.207013          0.250000      12
# 13     1655.891435        251.137986          0.083333      12
# 17      254.590662         73.203221          0.250000      12
# 33      423.449696        196.301885          0.300000      12
# 39    20071.075440        719.948985          0.333333      12
# ...            ...               ...               ...     ...
# 8936    605.716356         86.868595          0.750000       6
# 8940    475.523262         82.771320          1.000000       6
# 8942     94.488828         86.283101          0.250000       6
# 8945    325.594462         48.886365          0.500000       6
# 8947     81.270775         82.418369          0.250000       6
#
#       K_means_result  H_result  DBSCAN_result
# 12                 0         1              3
# 13                 0         1              3
# 17                 0         3              3
# 33                 0         3              3
# 39                 0         3              1
# ...              ...       ...            ...
# 8936               0         3              3
# 8940               0         3              3
# 8942               0         3              3
# 8945               0         3              3
# 8947               0         3              3
#
# [2241 rows x 20 columns]
